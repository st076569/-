# %%
#################################################################################
# Нейронные сети. Аппроксимация функции.                                        #
# Написать программу для обучения и тестирования нейронной сети приближающей    #
# значения заданной многомерной функции. Проверить качество нейронной сети на   #
# тестовой выборке (описать какими критериями пользовались).                    #
#################################################################################

# Импортируем нужные библиотеки
import numpy as np
import copy
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers

# Инициализация генератора случайных чисел
RANDOM_STATE = 4

# Размер тренировочной выборки
TRAIN_SIZE = 0.6

# Количество итераций обучения и кол-во примеров в группе
N_EPOCHS = 60
BATCH_SIZE = 10

# Пример одномерной функции 1 -> 1
def f11_1(x):
    return [-(x[0]) * (x[0]) + 5]

# Пример одномерной функции 1 -> 1
def f11_2(x):
    return [math.sin(x[0]) + 1]

# Пример одномерной функции 1 -> 1
def f11_3(x):
    return [math.sqrt(x[0])]

# Пример двумерной функции 2 -> 1
def f21_1(x):
    return [x[0] + x[1]]

# Пример двумерного отображения 2 -> 2
def f22_1(x):
    return [x[0] + x[1], x[1] * x[1] * x[0]]

# Сторит обучающую выборку для n-мерной функции
def createDotSet(f, dim, start, step, dotNumber):
    data = []
    target = []
    curDot = copy.deepcopy(start)
    dataSize = 1
    
    # Количество точек в пространстве, где рассчитываем значение f
    for i in range(dim):
        dataSize *= dotNumber[i];
    
    # Записываем точки и значения функции в этих точках
    for num in range(dataSize):
        numReduced = num
        for i in range(dim):
            curDot[i] = start[i] + step[i] * (numReduced % dotNumber[i])
            numReduced //= dotNumber[i]
        data.append(copy.deepcopy(curDot))
        target.append(f(curDot))
    return data, target

# Создаем обучающую и проверочную выборки
def createTrainTestSplit(data, train, trainSize):
     return train_test_split(data, train, train_size = trainSize, random_state = RANDOM_STATE)

# Создаем датасет точек пространства, сопоставляем им значения функции
data, target = createDotSet(f11_3, 1, [0], [0.01], [651])
#data, target = createDotSet(f21, 2, [0, 0], [0.1, 0.1], [21, 21])
#data, target = createDotSet(f22, 2, [0, 0], [0.1, 0.1], [21, 21])

# Создаем обучающую и тестировочную выборки
train_data, test_data, train_target, test_target = createTrainTestSplit(data, target, TRAIN_SIZE)

# Инициализируем слои перцептрона
inputs = keras.Input(shape=(1,))
x = layers.Dense(2000, activation='relu')(inputs)
y = layers.Dense(40, activation='relu')(x)
outputs = layers.Dense(1)(y)

# Предварительная подготовка двуслойного перцептрона
model = keras.Model(inputs=inputs, outputs=outputs, name='perceptron')
model.compile(optimizer='adam', loss='mae', metrics=['accuracy'])

# Обучение перцептрона
model.fit(train_data, train_target, epochs=N_EPOCHS, batch_size=BATCH_SIZE)

# Находим ошибку MeanAbsoluteError на тестовой выборке
mae = tf.keras.losses.MeanAbsoluteError()
print('\nMeanAbsoluteError: ', mae(test_target, model.predict(test_data)).numpy())
# Out:
# Epoch 1/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.3620 - accuracy: 0.0026
# Epoch 2/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.1121 - accuracy: 0.0000e+00
# Epoch 3/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0623 - accuracy: 0.0000e+00
# Epoch 4/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0441 - accuracy: 0.0000e+00
# Epoch 5/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0475 - accuracy: 0.0000e+00
# Epoch 6/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0413 - accuracy: 0.0026
# Epoch 7/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0370 - accuracy: 0.0026
# Epoch 8/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0464 - accuracy: 0.0026
# Epoch 9/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0436 - accuracy: 0.0026
# Epoch 10/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0376 - accuracy: 0.0026
# Epoch 11/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0279 - accuracy: 0.0026
# Epoch 12/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0435 - accuracy: 0.0026
# Epoch 13/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0394 - accuracy: 0.0026
# Epoch 14/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0532 - accuracy: 0.0026
# Epoch 15/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0514 - accuracy: 0.0026
# Epoch 16/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.
60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.0026
# Epoch 54/60
# 39/39 [==============================] - 0s 945us/step - loss: 0.0180 - accuracy: 0.0026
# Epoch 55/60
# 39/39 [==============================] - 0s 911us/step - loss: 0.0328 - accuracy: 0.0026
# Epoch 56/60
# 39/39 [==============================] - 0s 993us/step - loss: 0.0312 - accuracy: 0.0026
# Epoch 57/60
# 39/39 [==============================] - 0s 919us/step - loss: 0.0252 - accuracy: 0.0026
# Epoch 58/60
# 39/39 [==============================] - 0s 995us/step - loss: 0.0204 - accuracy: 0.0026
# Epoch 59/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0361 - accuracy: 0.0026
# Epoch 60/60
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0221 - accuracy: 0.0026
#
# MeanAbsoluteError:  0.009458272

# %%
#################################################################################
# Нейронные сети. Аппроксимация функции.                                        #
# Написать программу для обучения и тестирования нейронной сети приближающей    #
# значения заданной многомерной функции. Проверить качество нейронной сети на   #
# тестовой выборке (описать какими критериями пользовались).                    #
#################################################################################

# Импортируем нужные библиотеки
import numpy as np
import copy
import matplotlib.pyplot as plt
import tensorflow as tf
import math
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers

# Инициализация генератора случайных чисел
RANDOM_STATE = 1

# Размер тренировочной выборки
TRAIN_SIZE = 0.8

# Количество итераций обучения и кол-во примеров в группе
N_EPOCHS = 60
BATCH_SIZE = 20

# Пример одномерной функции 1 -> 1
def f11_1(x):
    return [-(x[0]) * (x[0]) + 5]

# Пример одномерной функции 1 -> 1
def f11_2(x):
    return [math.sin(x[0]) + 1]

# Пример одномерной функции 1 -> 1
def f11_3(x):
    return [math.sqrt(x[0])]

# Выводит аппроксимацию функции
def drawApproximation(X, Y1, Y2, Mae):
    fig, ax = plt.subplots(1, 2)
    fig.set_figwidth(16)
    fig.set_figheight(8)
    
    ax[0].set_title('Perceptron approximation')
    ax[1].set_title('MAE error')
    ax[0].axis([0, 7, 0, 3])
    ax[1].axis([0, 7, 0, 1])
    
    ax[1].plot(X, Mae, 'blue', label='MAE error')
    ax[0].plot(X, Y1, 'blue', label='Original')
    ax[0].plot(X, Y2, 'red', label='Approximation')
    
    ax[0].legend()
    ax[1].legend()
    plt.show()

# Сопоставляет каждой точке области задания величину отклонения
def createMaeSet(X, Y1, Y2, Mae):
    for i in range(len(X)):
        Mae[i] = abs(Y1[i] - Y2[i])

# Сторит обучающую выборку для n-мерной функции
def createDotSet(f, dim, start, step, dotNumber):
    data = []
    target = []
    curDot = copy.deepcopy(start)
    dataSize = 1
    
    # Количество точек в пространстве, где рассчитываем значение f
    for i in range(dim):
        dataSize *= dotNumber[i];
    
    # Записываем точки и значения функции в этих точках
    for num in range(dataSize):
        numReduced = num
        for i in range(dim):
            curDot[i] = start[i] + step[i] * (numReduced % dotNumber[i])
            numReduced //= dotNumber[i]
        data.append(copy.deepcopy(curDot))
        target.append(f(curDot))
    return data, target

# Создаем обучающую и проверочную выборки
def createTrainTestSplit(data, train, trainSize):
     return train_test_split(data, train, train_size = trainSize, random_state = RANDOM_STATE)

# Создаем датасет точек пространства, сопоставляем им значения функции
data, target = createDotSet(f11_3, 1, [0], [0.01], [651])

# Создаем обучающую и тестировочную выборки
train_data, test_data, train_target, test_target = createTrainTestSplit(data, target, TRAIN_SIZE)

# Инициализируем слои перцептрона
inputs = keras.Input(shape=(1,))
x = layers.Dense(2000, activation='relu')(inputs)
y = layers.Dense(40, activation='relu')(x)
outputs = layers.Dense(1)(y)

# Предварительная подготовка двуслойного перцептрона
model = keras.Model(inputs=inputs, outputs=outputs, name='perceptron')
model.compile(optimizer='adam', loss='mae', metrics=['accuracy'])

# Обучение перцептрона
model.fit(train_data, train_target, epochs=N_EPOCHS, batch_size=BATCH_SIZE)

# Находим ошибку MeanAbsoluteError на тестовой выборке
mae = tf.keras.losses.MeanAbsoluteError()
print('\nMeanAbsoluteError: ', mae(test_target, model.predict(test_data)).numpy())

# Изображаем аппроксимацию
pridiction = model.predict(data)
mae_set = createMaeSet(data, target, prediction)
drawApproximation(data, target, prediction, mae_set)
# Out:
# Epoch 1/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4233 - accuracy: 0.0000e+00
# Epoch 2/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1414 - accuracy: 0.0019
# Epoch 3/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0780 - accuracy: 0.0019
# Epoch 4/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0614 - accuracy: 0.0019
# Epoch 5/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0517 - accuracy: 0.0019
# Epoch 6/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0423 - accuracy: 0.0019
# Epoch 7/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0427 - accuracy: 0.0019
# Epoch 8/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0351 - accuracy: 0.0019
# Epoch 9/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0311 - accuracy: 0.0019
# Epoch 10/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0468 - accuracy: 0.0019
# Epoch 11/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0483 - accuracy: 0.0019
# Epoch 12/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0523 - accuracy: 0.0019
# Epoch 13/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0530 - accuracy: 0.0019
# Epoch 14/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0283 - accuracy: 0.0019
# Epoch 15/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0486 - accuracy: 0.0019
# Epoch 16/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0257 - accuracy: 0.0019
# Epoch 17/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0561 - accuracy: 0.0019
# Epoch 18/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0439 - accuracy: 0.0019
# Epoch 19/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0449 - accuracy: 0.0019
# Epoch 20/60
# 26/26 [==============================] - 0s 997us/step - loss: 0.0304 - accuracy: 0.0019
# Epoch 21/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0274 - accuracy: 0.0019
# Epoch 22/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0233 - accuracy: 0.0019
# Epoch 23/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0236 - accuracy: 0.0019
# Epoch 24/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0183 - accuracy: 0.0019
# Epoch 25/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0301 - accuracy: 0.0019
# Epoch 26/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.0019
# Epoch 27/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0194 - accuracy: 0.0019
# Epoch 28/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0168 - accuracy: 0.0019
# Epoch 29/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0176 - accuracy: 0.0019
# Epoch 30/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0324 - accuracy: 0.0019
# Epoch 31/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0180 - accuracy: 0.0019
# Epoch 32/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0186 - accuracy: 0.0019
# Epoch 33/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0204 - accuracy: 0.0019
# Epoch 34/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0325 - accuracy: 0.0019
# Epoch 35/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0398 - accuracy: 0.0019
# Epoch 36/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0294 - accuracy: 0.0019
# Epoch 37/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0126 - accuracy: 0.0019
# Epoch 38/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0311 - accuracy: 0.0019
# Epoch 39/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0499 - accuracy: 0.0019
# Epoch 40/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0227 - accuracy: 0.0019
# Epoch 41/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0209 - accuracy: 0.0019
# Epoch 42/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0159 - accuracy: 0.0019
# Epoch 43/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0157 - accuracy: 0.0019
# Epoch 44/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0435 - accuracy: 0.0019
# Epoch 45/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0152 - accuracy: 0.0019
# Epoch 46/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0143 - accuracy: 0.0019
# Epoch 47/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0232 - accuracy: 0.0019
# Epoch 48/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0177 - accuracy: 0.0019
# Epoch 49/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 0.0019
# Epoch 50/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0224 - accuracy: 0.0019
# Epoch 51/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0244 - accuracy: 0.0019
# Epoch 52/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0216 - accuracy: 0.0019
# Epoch 53/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0203 - accuracy: 0.0019
# Epoch 54/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0420 - accuracy: 0.0019
# Epoch 55/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0423 - accuracy: 0.0019
# Epoch 56/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0194 - accuracy: 0.0019
# Epoch 57/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0160 - accuracy: 0.0019
# Epoch 58/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0122 - accuracy: 0.0019
# Epoch 59/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0166 - accuracy: 0.0019
# Epoch 60/60
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0303 - accuracy: 0.0019
#
# MeanAbsoluteError:  0.028633647
